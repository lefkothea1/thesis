# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pykalman import KalmanFilter
import os

# %%
dir_in = 'D:\\arxeia\\AI_VU\\THESIS_internship\\3-experimental\\data\\allSensors_allPPs'
os.chdir(dir_in)

raw_df = pd.read_csv('all_data_FINAL.csv')
print(raw_df.shape)
raw_df.head()
# Out:
# (1200, 48)
#   pp_id condition  ts(sec)   frame  success  confidence  AU1_InnerBrowRaiser  \
# 0  pp02         N   60.163  1800.0      1.0    0.979333             0.124822
# 1  pp02         N  120.360  3600.0      1.0    0.975500             0.100794
# 2  pp02         N  180.556  5400.0      1.0    0.975056             0.181544
# 3  pp02         N  240.753  7200.0      1.0    0.977056             0.174183
# 4  pp02         N  300.950  9000.0      1.0    0.975194             0.141389
#
#    AU2_OuterBrowRaiser  AU4_BrowLowerer  AU5_UpperLipRaiser  ...  move_dist  \
# 0             0.181006         0.251717            0.095600  ...   5.659960
# 1             0.032833         0.130733            0.056844  ...  15.594104
# 2             0.064789         0.276167            0.064428  ...  19.806823
# 3             0.089906         0.139750            0.076000  ...   5.370893
# 4             0.032494         0.236983            0.069117  ...        NaN
#
#    move_duration   move_speed  scroll_dur  keyPress  press_dur  backsp  \
# 0       0.031436   703.808619         NaN        27   0.366753      27
# 1       0.023057  1940.534010         NaN       105   0.263460     105
# 2       0.023113  2461.080076         NaN       105   0.261484     105
# 3       0.023799   664.848872         NaN        45   0.272449      45
# 4            NaN          NaN         NaN       131   0.318532     131
#
#    backsp_dur  pause_dur  pause_rate
# 0    0.037037   2.830594    4.717656
# 1    0.028000   0.564831    0.941385
# 2    0.028778   0.495433    0.825721
# 3    0.099056   1.512937    2.521561
# 4    0.055815   0.417129    0.695215
#
# [5 rows x 48 columns]
